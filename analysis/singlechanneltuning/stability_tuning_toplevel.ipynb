# %% [markdown]
# # Toplevel Notebook for Stability and Tuning

# %% [markdown]
# ## Set up

# %% [markdown]
# ## Nicholas' New Stability and Tuning Stuff (Name TBD)

# %%
from plotters.NicholasStabilityTuning import stability_tuning_load
stability_tuning_load(outputdir)
# Out:
# ## Yearly Means ##
# Year 2020: 0.0454
# Year 2021: 0.0408
# Year 2022: 0.0384
# Year 2023: 0.0496
# Year 2024: 0.0254
#
# ## Distribution Comparisons Between Years ##
# Years        JS Div     KS Stat    KS p-val   t-stat     t p-val    Mean Diff
# ------------------------------------------------------------------------
# 2020-2021    0.0596    0.0510    1.47e-10  6.9926    2.85e-12  -0.0046
# 2020-2022    0.0795    0.0754    2.54e-20  10.2250    1.93e-24  -0.0069
# 2020-2023    0.1218    0.1308    6.34e-42  -4.8693    1.14e-06  0.0042
# 2020-2024    0.4005    0.3364    2.68e-19  10.2495    1.65e-20  -0.0200
# 2021-2022    0.0492    0.0329    2.91e-06  4.6439    3.44e-06  -0.0024
# 2021-2023    0.1406    0.1695    1.00e-92  -11.9940    7.49e-33  0.0088
# 2021-2024    0.3994    0.3311    4.59e-19  8.1182    4.45e-14  -0.0154
# 2022-2023    0.1431    0.1833    1.98e-99  -14.7969    6.37e-49  0.0111
# 2022-2024    0.3913    0.3306    6.53e-19  6.8491    8.31e-11  -0.0130
# ...
