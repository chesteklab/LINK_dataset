# %% [markdown]
# # Plot Figures in Paper

# %% [markdown]
# ### (Action Required) Preparations

# %%
# data_path = "Z:\Student Folders\\Nina_Gill\data\only_good_days"
# output_path = 'Z:\Student Folders\Hisham_Temmar\\big_dataset\output\single_channel_tuning'

# (for debugging stage) please dont remove these, comment them out would be fine. otherwise ill have to write the directories again which is annoying because windows hates single \
data_path = "/home/chang/Desktop/990Pro/ND/github/LINK_dataset/data/pickles"
output_path = '/home/chang/Desktop/990Pro/ND/github/LINK_dataset/outputs'

# BCI results folder
results_folder = "/home/chang/Desktop/990Pro/ND/github/LINK_dataset/data_processing/bci_decoding/single_day_model_results"

# %% [markdown]
# ### (Action Not Required) Preparations (TODO: silly name change later)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Debugging stuff:

# %%
#python generate_figures.py --data_dir "C:\\Files\\UM\\ND\\SFN\\only_good_days" --output_dir "C:\\Files\\UM\\ND\\github\\big_nhp_dataset_code\\outputs"
#
#python generate_figures.py --plot dataset_overview --data_dir "C:\\Files\\UM\\ND\\SFN\\only_good_days" --output_dir "C:\\Files\\UM\\ND\\github\\big_nhp_dataset_code\\outputs"

# %%
from data_processing.bci_decoding import creat_all_decoding_figures
creat_all_decoding_figures(results_folder, output_path)
# Out:
# Number of same-day evaluations - RR: 330, LSTM: 330
# Date range: 2020-01-27 to 2023-06-22, spanning 1242 days
#
# Aggregated data shapes - RR: (201, 10) LSTM: (201, 10)
# Number of same-day evaluations - RR: 330, LSTM: 330
# Date range: 2020-01-27 to 2023-06-22, spanning 1242 days
#
# Aggregated data shapes - RR: (201, 10) LSTM: (201, 10)

# %%
from data_processing.pop_level_analyses import create_dimensionality_across_days_figures
create_dimensionality_across_days_figures(data_path,output_path)
# Out:
# /media/chang/990Pro/ND/github/LINK_dataset
# Processing datasets:   4%|▎         | 11/303 [00:00<00:02, 106.94it/s]
# 303
# Processing datasets: 100%|██████████| 303/303 [00:02<00:00, 108.46it/s]
# 2020
# 2023
# Made trial classes
# (7484726, 96)
# Grouped Data
# /media/chang/990Pro/ND/github/LINK_dataset/data_processing/pop_level_analyses/population_level_analyses.py:998: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(left=0.1, right=1.1, top=0.9, bottom=0.1)

# %%
from data_processing.dataset_overview import create_dataset_overview_figure
create_dataset_overview_figure(data_path, output_path)

# %%
from data_processing.signal_changes import create_signal_quality_figure
create_signal_quality_figure(data_path, output_path, calc_avg_sbp=True,calculate_pr=True)
# Out:
# Found 303 dates
# ...
# 100%|██████████| 303/303 [00:06<00:00, 46.26it/s]

# %% [markdown]
# #

# %%
from data_processing.single_channel_tuning import create_single_channel_tuning_figure
create_single_channel_tuning_figure(data_path, output_path)
# Out:
# Directory /home/chang/Desktop/990Pro/ND/github/LINK_dataset/outputs/channel_stability_tuning.csv does not exist or overwrite, computing tuning data
# Processing files in /home/chang/Desktop/990Pro/ND/github/LINK_dataset/data/pickles: 100%|██████████| 303/303 [03:53<00:00,  1.30it/s]
# Data saved to /home/chang/Desktop/990Pro/ND/github/LINK_dataset/outputs/channel_stability_tuning.csv
# /media/chang/990Pro/ND/github/LINK_dataset/data_processing/single_channel_tuning/tuning_plotter.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['0°','45°', '90°','135°', '180°','-135°','-90°','-45°','-180°'])
# /media/chang/990Pro/ND/github/LINK_dataset/data_processing/single_channel_tuning/tuning_plotter.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...
