# %% [markdown]
# # Repository Usage Examples

# %% [markdown]
# ### (Action Required) Preparations

# %%
# data_path = "Z:\Student Folders\\Nina_Gill\data\only_good_days"
# output_path = 'Z:\Student Folders\Hisham_Temmar\\big_dataset\output\single_channel_tuning'

# (for debugging stage) please dont remove these, comment them out would be fine. otherwise ill have to write the directories again which is annoying because windows hates single \
data_path = "C:\\Files\\UM\\ND\\SFN\\only_good_days"
output_path = 'C:\\Files\\UM\\ND\\github\\big_nhp_dataset_code\\outputs'

# %% [markdown]
# ### (Action Not Required) Preparations (TODO: silly name change later)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Debugging stuff:

# %%
python generate_figures.py --data_dir "C:\\Files\\UM\\ND\\SFN\\only_good_days" --output_dir "C:\\Files\\UM\\ND\\github\\big_nhp_dataset_code\\outputs"
python generate_figures.py --plot dataset_overview --data_dir "C:\\Files\\UM\\ND\\SFN\\only_good_days" --output_dir "C:\\Files\\UM\\ND\\github\\big_nhp_dataset_code\\outputs"
# Out:
#   Cell In[23], line 1
#     python generate_figures.py --data_dir "C:\\Files\\UM\\ND\\SFN\\only_good_days" --output_dir "C:\\Files\\UM\\ND\\github\\big_nhp_dataset_code\\outputs"
#            ^
# SyntaxError: invalid syntax

# %%
from analysis.pop_level_analyses import create_dimensionality_across_days_figures
create_dimensionality_across_days_figures(data_path)
# Out:
# c:\Files\UM\ND\github\big_nhp_dataset_code
# Processing datasets:   3%|▎         | 8/303 [00:00<00:03, 75.08it/s]
# 303
# Processing datasets: 100%|██████████| 303/303 [00:04<00:00, 60.67it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 from analysis.pop_level_analyses import create_dimensionality_across_days_figures
# ----> 2 create_dimensionality_across_days_figures(data_path)
#
# File c:\Files\UM\ND\github\big_nhp_dataset_code\analysis\pop_level_analyses\dimensionality_across_days_analysis.py:21, in create_dimensionality_across_days_figures(data_path)
#      19 ### LOAD AND PREPROCESS DATA ###
#      20 df_tuning = prepare_tuning_data(results)
# ---> 21 plot_avg_trajectories(df_tuning, type_of_data='sbps', group_by = 'year', trim_method = trim_neural_data_at_movement_onset_std_and_smooth, trim_pt = max_jerk, sigma = .5, years_to_skip=[2021, 2022], directions='ext_flex', remove_RT=False)
#      22 plot_centroid_of_pca_data_across_time(df_tuning, group_by='quarter', remove_RT=False, normalization_method = 'all', years_to_skip = [], plot_centr_across_time=True)
#
# File c:\Files\UM\ND\github\big_nhp_dataset_code\analysis\pop_level_analyses\population_level_analyses.py:1327, in plot_avg_trajectories(df_tuning, type_of_data, group_by, display_alignment, directions, trim_method, trim_pt, years_to_skip, sigma, remove_RT)
#    1323 for i, time_period in enumerate(time_periods):
#    1325     color_dict[str(time_period)] = colors[i]
# -> 1327 neural_data_for_direction, _ = split(df_time=df_time, time_periods=time_periods, type_of_data=type_of_data, kinematic_type='vel', position_map = position_map, only_CO=remove_RT)
#    1329 processed_neural_data_for_direction, kinematics_data = trim_method(neural_data_for_direction, std_multiplier=2, sigma=sigma, display_alignment=display_alignment, trim_pt = trim_pt, direction_key = direction_key)
#    1331 averaged_pca_results, averaged_kin_results = average_trial_PCA_data(dir_list=dir_list, kinematics=kinematics_data, processed_neural_data_for_direction=processed_neural_data_for_direction)
#
# File c:\Files\UM\ND\github\big_nhp_dataset_code\analysis\pop_level_analyses\population_level_analyses.py:1088, in split(df_time, time_periods, position_map, type_of_data, jpca, kinematic_type, only_CO)
#    1085 trial_length = yearly_data['trial_counts'][i]
#    1087 target_pos_coords = tuple(yearly_data['target_positions'][i])
# -> 1088 target_pos_coords = (round(float(target_pos_coords[0]), 1), round(float(target_pos_coords[1]), 1))
#    1089 if target_pos_coords in position_map: # skips (0.5, 0.5)
#    1091     target_pos = position_map[target_pos_coords]
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
from analysis.dataset_overview import create_dataset_overview_figure
create_dataset_overview_figure(data_path, output_path)

# %%
from analysis.signal_changes import create_signal_quality_figure
create_signal_quality_figure(data_path, output_path, calc_avg_sbp=True,calculate_pr=True)
# Out:
# Found 303 dates
# 100%|██████████| 303/303 [00:06<00:00, 48.48it/s]
# 100%|██████████| 303/303 [00:15<00:00, 19.56it/s]

# %% [markdown]
# #

# %%
from analysis.single_channel_tuning import create_single_channel_tuning_figure
create_single_channel_tuning_figure(data_path, output_path)
# Out:
# c:\Files\UM\ND\github\big_nhp_dataset_code\analysis\single_channel_tuning\tuning_plotter.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['0°','45°', '90°','135°', '180°','-135°','-90°','-45°','-180°'])
# Ch. 7 perday FR: 3.12 +/- 10.24
# c:\Files\UM\ND\github\big_nhp_dataset_code\analysis\single_channel_tuning\tuning_plotter.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['0°','45°', '90°','135°', '180°','-135°','-90°','-45°','-180°'])
# Ch. 32 perday FR: 36.45 +/- 20.73
# c:\Files\UM\ND\github\big_nhp_dataset_code\analysis\single_channel_tuning\single_channel_tuning.py:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   avg_tuning_ax[i].set_xticklabels(['0°','45°', '90°','135°', '180°','-135°','-90°','-45°'])
# c:\Files\UM\ND\github\big_nhp_dataset_code\analysis\single_channel_tuning\single_channel_tuning.py:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   avg_tuning_ax[i].set_xticklabels(['0°','45°', '90°','135°', '180°','-135°','-90°','-45°'])
# c:\Files\UM\ND\github\big_nhp_dataset_code\analysis\single_channel_tuning\single_channel_tuning.py:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   avg_tuning_ax[i].set_xticklabels(['0°','45°', '90°','135°', '180°','-135°','-90°','-45°'])
